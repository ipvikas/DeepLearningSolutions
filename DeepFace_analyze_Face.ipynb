# %% [markdown]
# Deepface is a lightweight face recognition and facial attribute analysis (age, gender, emotion and race) framework for python. It is a hybrid face recognition framework wrapping state-of-the-art models: VGG-Face, Google FaceNet, OpenFace, Facebook DeepFace, DeepID, ArcFace and Dlib.
#
# Experiments show that human beings have 97.53% accuracy on facial recognition tasks whereas those models already reached and passed that accuracy level.

# %%
# !pip install deepface
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 65 kB 2.8 MB/s
# ...
#      |████████████████████████████████| 87 kB 7.1 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 62.3 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=b2227561728bfae2f16f0b1655b2cfe4b754792a33ba06649754d9f9a8d9b4a7
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# ...

# %%
from deepface import DeepFace
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
from google.colab import drive
drive.mount('/content/drive')
img1_path = '/content/drive/My Drive/Colab Notebooks/DeepLearning/FaceRecognition/PhotoDataSet/10Jan_1.jpeg'
# img2_path = '/content/drive/My Drive/Colab Notebooks/DeepLearning/FaceRecognition/PhotoDataSet/11Jan_1.jpeg'


img2_path = '/content/drive/My Drive/Colab Notebooks/DeepLearning/FaceRecognition/PhotoDataSet/Shaurya_2011.jpg'
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
image1 = Image.open(img1_path)
image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x1280 at 0x7F9ECF34AC10>

# %%
from PIL import Image
image2 = Image.open(img2_path)
image2
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import matplotlib.pyplot as plt
img1_detect= DeepFace.detectFace(img1_path)
img2_detect= DeepFace.detectFace(img2_path)

# plt.imshow(img1_detect)

plt.imshow(img2_detect)

# %%
model_name = 'ArcFace'  #VGG-Face, Facenet, OpenFace, DeepFace, DeepID, Dlib, ArcFace or Ensemble
#IMP change "model_name" and see how values are changing
#verified "False" means both the images are different 
DeepFace.verify(img1_path=img1_path,img2_path=img2_path,model_name = model_name)
# Out:
# arcface_weights.h5  will be downloaded to  /root/.deepface/weights/arcface_weights.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5
# To: /root/.deepface/weights/arcface_weights.h5
# 100%|██████████| 137M/137M [00:02<00:00, 67.6MB/s]
# {'verified': False,
#  'distance': 0.9793274565397335,
#  'threshold': 0.68,
#  'model': 'ArcFace',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine'}

# %% [markdown]
#  VGG-Face: {'distance': 0.15456985647922383,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine',
#  'verified': True}
#
# Facenet: {'distance': 0.3427554272297687,
#  'max_threshold_to_verify': 0.4,
#  'model': 'Facenet',
#  'similarity_metric': 'cosine',
#  'verified': True}
#
#  OpenFace: {'distance': 0.17495993541869803,
#  'max_threshold_to_verify': 0.1,
#  'model': 'OpenFace',
#  'similarity_metric': 'cosine',
#  'verified': False}
#
#  DeepFace: {'distance': 0.19016289340949155,
#  'max_threshold_to_verify': 0.23,
#  'model': 'DeepFace',
#  'similarity_metric': 'cosine',
#  'verified': True}
#
#  DeepID: {'distance': 0.01621247772401424,
#  'max_threshold_to_verify': 0.015,
#  'model': 'DeepID',
#  'similarity_metric': 'cosine',
#  'verified': False}
#
#  Dlib: RuntimeError: Error while calling cudaGetDevice(&the_device_id) in file /tmp/pip-wheel-mmuzni47/dlib/dlib/cuda/gpu_data.cpp:201. code: 100, reason: no CUDA-capable device is detected
#
#  ArcFace: {'distance': 0.3245536078618674,
#  'max_threshold_to_verify': 0.68,
#  'model': 'ArcFace',
#  'similarity_metric': 'cosine',
#  'verified': True}
#
#  Ensemble: {'distance': [0.15456985647922383,
#   0.3241030598308172,
#   0.5560033389813841,
#   0.3427554272297687,
#   10.289516524902647,
#   0.8279558288094463,
#   0.21141447729014495,
#   0.6502529927499683,
#   0.19016289340949155,
#   53.59632249297718,
#   0.6167055916877869],
#  'model': ['VGG-Face', 'Facenet', 'OpenFace', 'DeepFace'],
#  'score': 0.9969200768482246,
#  'similarity_metric': ['cosine', 'euclidean', 'euclidean_l2'],
#  'verified': True}

# %%
#ALL as a whole
# !pip install deepface
from deepface import DeepFace

from google.colab import drive
drive.mount('/content/drive')
img1_path = '/content/drive/My Drive/Colab Notebooks/DeepLearning/FaceRecognition/PhotoDataSet/10Jan_1.jpeg'
img2_path = '/content/drive/My Drive/Colab Notebooks/DeepLearning/FaceRecognition/PhotoDataSet/Shaurya_2011.jpg'

import matplotlib.pyplot as plt
img1_detect= DeepFace.detectFace(img1_path)
img2_detect= DeepFace.detectFace(img2_path)

model_name = 'ArcFace'  #VGG-Face, Facenet, OpenFace, DeepFace, DeepID, Dlib, ArcFace or Ensemble
#IMP change "model_name" and see how values are changing
#verified "False" means both the images are different 
DeepFace.verify(img1_path=img1_path,img2_path=img2_path,model_name = model_name)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 65 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 87 kB 7.9 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 59.6 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=3fa762e0e7e326e4e472fc034c2d2f5077188359aa3189a9cc3b02c0987b0bee
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# ...
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created
# Mounted at /content/drive
# arcface_weights.h5  will be downloaded to  /root/.deepface/weights/arcface_weights.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5
# To: /root/.deepface/weights/arcface_weights.h5
# 100%|██████████| 137M/137M [00:04<00:00, 28.8MB/s]
# {'verified': False,
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
img1_source_path = '/content/drive/My Drive/Colab Notebooks/DeepLearning/FaceRecognition/Source/src_vik2_1.jpg'

from PIL import Image
image1_source = Image.open(img1_source_path)
image1_source
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=179x426 at 0x7F9E180C1A50>

# %%
import pandas as pd

df = DeepFace.find(img_path=img1_source_path, db_path='/content/drive/My Drive/Colab Notebooks/DeepLearning/FaceRecognition/PhotoDataSet/')
#df = DeepFace.find(img_path=img1_source_path, db_path='/content/drive/My Drive/Colab Notebooks/DeepLearning/Opencv/Faces/train/Vikas')
df.head()
# Out:
# vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /root/.deepface/weights/vgg_face_weights.h5
# 100%|██████████| 580M/580M [00:07<00:00, 82.5MB/s]
# WARNING: Representations for images in  /content/drive/My Drive/Colab Notebooks/DeepLearning/FaceRecognition/PhotoDataSet/  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  129  representations found in  representations_vgg_face.pkl
# find function lasts  9.991591691970825  seconds
#                                             identity  VGG-Face_cosine
# 0  /content/drive/My Drive/Colab Notebooks/DeepLe...         0.210135
# 1  /content/drive/My Drive/Colab Notebooks/DeepLe...         0.228634
# 2  /content/drive/My Drive/Colab Notebooks/DeepLe...         0.235888
# ...

# %%
DeepFace.analyze(img_path=img1_path)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 70.7MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
# 100%|██████████| 539M/539M [00:26<00:00, 20.3MB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: /root/.deepface/weights/gender_model_weights.h5
# 100%|██████████| 537M/537M [00:23<00:00, 22.5MB/s]
# race_model_single_batch.h5 will be downloaded...
# Downloading...
# ...

# %%
#IMPORTANT PART ONLY
# !pip install deepface
from deepface import DeepFace
from google.colab import drive
drive.mount('/content/drive')
img1_path = '/content/drive/My Drive/Colab Notebooks/DeepLearning/FaceRecognition/PhotoDataSet/10Jan_1.jpeg'

import pandas as pd
df = DeepFace.find(img_path=img1_path, db_path='/content/drive/My Drive/Colab Notebooks/DeepLearning/FaceRecognition/PhotoDataSet/')
print(df.head())
print(DeepFace.analyze(img_path=img1_path))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 65 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 87 kB 7.5 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 61.3 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=a7282fb5e1ebd133be7976f55388ec8e1d15d4b1621a737628c7dd02927d2ce1
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# ...
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created
# Mounted at /content/drive
# vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /root/.deepface/weights/vgg_face_weights.h5
# 100%|██████████| 580M/580M [00:07<00:00, 74.7MB/s]
# ...

# %%
print(DeepFace.analyze(img_path=img1_path))
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  3.66it/s]
# {'emotion': {'angry': 0.0527393775998059, 'disgust': 5.5690908528933406e-08, 'fear': 0.001257097269235831, 'happy': 13.268640729026881, 'sad': 0.5913899053799994, 'surprise': 0.00041571102382301916, 'neutral': 86.08555627889112}, 'dominant_emotion': 'neutral', 'region': {'x': 278, 'y': 142, 'w': 182, 'h': 182}, 'age': 31, 'gender': 'Man', 'race': {'asian': 5.055751580342744, 'indian': 29.354824385334513, 'black': 3.717558307502169, 'white': 11.013635159351537, 'middle eastern': 19.7417107070512, 'latino hispanic': 31.116523213179303}, 'dominant_race': 'latino hispanic'}

# %%
type(DeepFace.analyze(img_path=img1_path))
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  3.14it/s]
# dict
